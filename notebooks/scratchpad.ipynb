# %%
from collections import defaultdict
counter = defaultdict(int)
print(counter["test"])
# Out:
# 0

# %%
strs = ["flower","low","flight"]
for i in zip(*strs):
    print(len(set(i)))
# Out:
# 2
# 2
# 3

# %%
nums = [1,3,-1,-3,5,3,6,7]
k = 3

# %%
heap = [(-nums[x], x) for x in range(k-1)]

# %%
heap
# Out:
# [(-1, 0), (-3, 1)]

# %%
import heapq


heapq.heapify(heap)

# %%
heap
